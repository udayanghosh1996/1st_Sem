# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
dataset=pd.read_csv("dataset.csv")
dataset.shape
dataset
# Out:
#      size    weight  skincolor  target
# 0      35  0.571539        139       0
# 1      23  5.348117        184       0
# 2      38  3.419377        126       0
# 3      34  3.323665        137       0
# 4      34  1.453573        198       0
# ..    ...       ...        ...     ...
# 195    17  0.654607        194       1
# 196    21  0.543074        160       1
# 197    24  0.622039        191       1
# 198    23  0.385931        279       1
# 199    19  0.852708        172       1
#
# [200 rows x 4 columns]

# %%
papaya=dataset[dataset[0,3]==0]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3620             try:
# -> 3621                 return self._engine.get_loc(casted_key)
#    3622             except KeyError as err:
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\AppData\Roaming\Python\Python39\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: (0, 3)
#
# The above exception was the direct cause of the following exception:
#
# ...
