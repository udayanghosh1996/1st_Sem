# %%
# %autosave 1
# Out:
# Autosaving every 1 seconds

# %%
import numpy as np
import torch
import torchvision
from time import time
from torchvision import datasets, transforms
from torch import nn, optim
import os
from torch.utils.data import DataLoader, dataloader
from torch import nn
from torch.autograd import Variable
import matplotlib.pyplot as plt

# %%
transform=transforms.Compose([transforms.ToTensor()])
path=os.getcwd()
trainset = datasets.MNIST(os.path.join(path,'Train'), download=True, train=True, transform=transform)
valset = datasets.MNIST(os.path.join(path,'Train'), download=True, train=False, transform=transform)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=64, shuffle=True)
val_loader = torch.utils.data.DataLoader(valset, batch_size=64, shuffle=True)

# %%
dataiter = iter(train_loader)
images, labels = dataiter.next()
print(images.shape)
print(labels.shape)
# Out:
# torch.Size([64, 1, 28, 28])
# torch.Size([64])

# %%
class Mnist(nn.Module):
    def __init__(self):
        super(Mnist,self).__init__()
        self.layer1 = nn.Linear(784,392)
        self.layer2 = nn.Linear(392,196)
        self.Final = nn.Linear(196,10)
        self.relu = nn.ReLU()
        self.softmax = nn.Softmax()
    def forward(self, data):
        mtx = torch.flatten(data, start_dim=1)
        mtx = self.layer1(mtx)
        mtx = self.relu(mtx)
        mtx = self.layer2(mtx)
        mtx = self.relu(mtx)
        mtx = self.Final(mtx)
        #mtx = self.softmax(mtx)
        return mtx

# %%
criterion = nn.CrossEntropyLoss()
model = Mnist()
optimizer = optim.SGD(model.parameters(), lr=0.0014, momentum=0.9)
epochs = 30
time0 = time()

for e_no in range(1, epochs+1):
    running_loss = 0
    batch_no = 0
    correct = 0 
    total = 0
    for images, labels in train_loader:
        batch_no += 1
        model.train()
        images = images.flatten(start_dim=1)
        optimizer.zero_grad()
        output = model(images)
        _, output_index = output.topk(1)
        result = labels.numpy() == output_index.numpy().reshape(-1,)
        correct += result.sum()
        total += len(labels)
        loss = criterion(output, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
    else:
        print("Epoch {} - Training Loss: {}".format(e_no, running_loss/len(train_loader)))
        print(f"Training Accuracy: {(correct/total) * 100}")
        print("Training Time in Minute=",(time()-time0)/60)
        model.eval()
        correct = 0
        total = 0
        for val_images, vlabels in val_loader:
            val_images = val_images.flatten(start_dim=1)
            val_output = model(val_images)
            _, output_idx = val_output.topk(1)
            res = vlabels.numpy() == output_idx.numpy().reshape(-1,)
            correct += res.sum()
            total += len(vlabels)
            
        print(f"Validation Accuracy: {(correct * 100) / total}\n")
# Out:
# Epoch 1 - Training Loss: 1.3542694641964268
# Training Accuracy: 68.155
# Training Time in Minute= 0.11687628030776978
# Validation Accuracy: 86.7
#
# Epoch 2 - Training Loss: 0.42018315084834595
# Training Accuracy: 88.47500000000001
# Training Time in Minute= 0.24992614189783732
# Validation Accuracy: 90.24
#
# Epoch 3 - Training Loss: 0.3349129601614053
# Training Accuracy: 90.485
# Training Time in Minute= 0.37395373980204266
# Validation Accuracy: 91.39
#
# Epoch 4 - Training Loss: 0.29650300601398005
# Training Accuracy: 91.51333333333334
# Training Time in Minute= 0.49823850790659585
# Validation Accuracy: 92.32
#
# Epoch 5 - Training Loss: 0.26861870274551386
# Training Accuracy: 92.25166666666667
# Training Time in Minute= 0.6258371472358704
# Validation Accuracy: 92.95
#
# Epoch 6 - Training Loss: 0.24470773310279414
# Training Accuracy: 93.00500000000001
# Training Time in Minute= 0.7517829378445943
# Validation Accuracy: 93.61
#
# Epoch 7 - Training Loss: 0.22361539879730388
# Training Accuracy: 93.62333333333333
# Training Time in Minute= 0.8788284540176392
# Validation Accuracy: 93.94
#
# Epoch 8 - Training Loss: 0.2055577602721989
# Training Accuracy: 94.09333333333333
# Training Time in Minute= 1.0084811210632325
# Validation Accuracy: 94.34
#
# Epoch 9 - Training Loss: 0.18928603605547947
# Training Accuracy: 94.63166666666667
# Training Time in Minute= 1.134491233030955
# Validation Accuracy: 94.79
#
# Epoch 10 - Training Loss: 0.17526331636856105
# Training Accuracy: 94.97666666666666
# Training Time in Minute= 1.272028394540151
# Validation Accuracy: 95.1
#
# Epoch 11 - Training Loss: 0.1631436444648198
# Training Accuracy: 95.345
# Training Time in Minute= 1.4012754201889037
# Validation Accuracy: 95.36
#
# Epoch 12 - Training Loss: 0.15245753034019965
# Training Accuracy: 95.67333333333333
# Training Time in Minute= 1.5269996166229247
# Validation Accuracy: 95.58
#
# Epoch 13 - Training Loss: 0.14234304177894522
# Training Accuracy: 95.91499999999999
# Training Time in Minute= 1.6556300838788351
# Validation Accuracy: 95.82
#
# Epoch 14 - Training Loss: 0.13354142989192816
# Training Accuracy: 96.17
# Training Time in Minute= 1.7820356249809266
# Validation Accuracy: 96.08
#
# Epoch 15 - Training Loss: 0.12566814966984333
# Training Accuracy: 96.42833333333334
# Training Time in Minute= 1.9120846311251323
# Validation Accuracy: 96.3
#
# Epoch 16 - Training Loss: 0.11798206661174547
# Training Accuracy: 96.58666666666666
# Training Time in Minute= 2.0378396193186443
# Validation Accuracy: 96.44
#
# Epoch 17 - Training Loss: 0.11171952323483697
# Training Accuracy: 96.78166666666667
# Training Time in Minute= 2.1655460158983866
# Validation Accuracy: 96.54
#
# Epoch 18 - Training Loss: 0.10524191804675025
# Training Accuracy: 96.96333333333334
# Training Time in Minute= 2.3044713020324705
# Validation Accuracy: 96.65
#
# Epoch 19 - Training Loss: 0.09970633929142597
# Training Accuracy: 97.20833333333333
# Training Time in Minute= 2.434929597377777
# Validation Accuracy: 96.79
#
# Epoch 20 - Training Loss: 0.09482533322758417
# Training Accuracy: 97.315
# Training Time in Minute= 2.562557888031006
# Validation Accuracy: 96.82
#
# Epoch 21 - Training Loss: 0.0894783645687597
# Training Accuracy: 97.50166666666667
# Training Time in Minute= 2.690083595116933
# Validation Accuracy: 97.0
#
# Epoch 22 - Training Loss: 0.0852063210871714
# Training Accuracy: 97.61166666666666
# Training Time in Minute= 2.8167025685310363
# Validation Accuracy: 97.08
#
# Epoch 23 - Training Loss: 0.08101203667917359
# Training Accuracy: 97.735
# Training Time in Minute= 2.9428972760836283
# Validation Accuracy: 97.11
#
# Epoch 24 - Training Loss: 0.07739925255397283
# Training Accuracy: 97.81333333333333
# Training Time in Minute= 3.0695088187853496
# Validation Accuracy: 97.08
#
# Epoch 25 - Training Loss: 0.0736087757487422
# Training Accuracy: 97.92999999999999
# Training Time in Minute= 3.205336062113444
# Validation Accuracy: 97.28
#
# Epoch 26 - Training Loss: 0.07002596991823744
# Training Accuracy: 98.06833333333333
# Training Time in Minute= 3.3331658641497293
# Validation Accuracy: 97.32
#
# Epoch 27 - Training Loss: 0.0665635255032352
# Training Accuracy: 98.13166666666666
# Training Time in Minute= 3.461989684899648
# Validation Accuracy: 97.27
#
# Epoch 28 - Training Loss: 0.06369727787905252
# Training Accuracy: 98.24333333333334
# Training Time in Minute= 3.5908016244570415
# Validation Accuracy: 97.39
#
# Epoch 29 - Training Loss: 0.06110325327137116
# Training Accuracy: 98.29333333333334
# Training Time in Minute= 3.720337756474813
# Validation Accuracy: 97.6
#
# Epoch 30 - Training Loss: 0.05842087359608475
# Training Accuracy: 98.39333333333333
# Training Time in Minute= 3.8481302777926127
# Validation Accuracy: 97.56
